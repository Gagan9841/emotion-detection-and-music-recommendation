# %% [markdown]
# # Facial Emotion Recognition | VGG19 Model

# %% [markdown]
# ## Library

# %%
# !pip install mlflow
# Out:
# Collecting mlflow
#   Obtaining dependency information for mlflow from https://files.pythonhosted.org/packages/19/7a/7d5594ddcaaff7a92caed1d7822cfe52ed01fe06c94b4ad88bcfef579c32/mlflow-2.15.1-py3-none-any.whl.metadata
#   Downloading mlflow-2.15.1-py3-none-any.whl.metadata (29 kB)
# Collecting mlflow-skinny==2.15.1 (from mlflow)
#   Obtaining dependency information for mlflow-skinny==2.15.1 from https://files.pythonhosted.org/packages/ec/a1/3812743e5dd83317d0469a46d737f0ab5c084fecfecc03a1ac8a7e7ec0d8/mlflow_skinny-2.15.1-py3-none-any.whl.metadata
#   Downloading mlflow_skinny-2.15.1-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: Flask<4 in c:\users\bishw\anaconda3\lib\site-packages (from mlflow) (2.2.2)
# Collecting alembic!=1.10.0,<2 (from mlflow)
#   Obtaining dependency information for alembic!=1.10.0,<2 from https://files.pythonhosted.org/packages/df/ed/c884465c33c25451e4a5cd4acad154c29e5341e3214e220e7f3478aa4b0d/alembic-1.13.2-py3-none-any.whl.metadata
#   Downloading alembic-1.13.2-py3-none-any.whl.metadata (7.4 kB)
# Collecting docker<8,>=4.0.0 (from mlflow)
#   Obtaining dependency information for docker<8,>=4.0.0 from https://files.pythonhosted.org/packages/e3/26/57c6fb270950d476074c087527a558ccb6f4436657314bfb6cdf484114c4/docker-7.1.0-py3-none-any.whl.metadata
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting graphene<4 (from mlflow)
#   Obtaining dependency information for graphene<4 from https://files.pythonhosted.org/packages/24/70/96f6027cdfc9bb89fc07627b615cb43fb1c443c93498412beaeaf157e9f1/graphene-3.3-py2.py3-none-any.whl.metadata
#   Downloading graphene-3.3-py2.py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: markdown<4,>=3.3 in c:\users\bishw\anaconda3\lib\site-packages (from mlflow) (3.4.1)
# Requirement already satisfied: matplotlib<4 in c:\users\bishw\anaconda3\lib\site-packages (from mlflow) (3.7.2)
# Requirement already satisfied: numpy<2 in c:\users\bishw\anaconda3\lib\site-packages (from mlflow) (1.24.3)
# Requirement already satisfied: pandas<3 in c:\users\bishw\anaconda3\lib\site-packages (from mlflow) (2.0.3)
# Requirement already satisfied: pyarrow<16,>=4.0.0 in c:\users\bishw\anaconda3\lib\site-packages (from mlflow) (11.0.0)
# Collecting querystring-parser<2 (from mlflow)
#   Obtaining dependency information for querystring-parser<2 from https://files.pythonhosted.org/packages/88/6b/572b2590fd55114118bf08bde63c0a421dcc82d593700f3e2ad89908a8a9/querystring_parser-1.2.4-py2.py3-none-any.whl.metadata
#   Downloading querystring_parser-1.2.4-py2.py3-none-any.whl.metadata (559 bytes)
# Requirement already satisfied: scikit-learn<2 in c:\users\bishw\anaconda3\lib\site-packages (from mlflow) (1.3.0)
# Requirement already satisfied: scipy<2 in c:\users\bishw\anaconda3\lib\site-packages (from mlflow) (1.11.1)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in c:\users\bishw\anaconda3\lib\site-packages (from mlflow) (1.4.39)
# Requirement already satisfied: Jinja2<4,>=3.0 in c:\users\bishw\anaconda3\lib\site-packages (from mlflow) (3.1.2)
# Collecting waitress<4 (from mlflow)
#   Obtaining dependency information for waitress<4 from https://files.pythonhosted.org/packages/5b/a9/485c953a1ac4cb98c28e41fd2c7184072df36bbf99734a51d44d04176878/waitress-3.0.0-py3-none-any.whl.metadata
#   Downloading waitress-3.0.0-py3-none-any.whl.metadata (4.2 kB)
# Collecting cachetools<6,>=5.0.0 (from mlflow-skinny==2.15.1->mlflow)
#   Obtaining dependency information for cachetools<6,>=5.0.0 from https://files.pythonhosted.org/packages/a4/07/14f8ad37f2d12a5ce41206c21820d8cb6561b728e51fad4530dff0552a67/cachetools-5.5.0-py3-none-any.whl.metadata
#   Downloading cachetools-5.5.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: click<9,>=7.0 in c:\users\bishw\anaconda3\lib\site-packages (from mlflow-skinny==2.15.1->mlflow) (8.0.4)
# Requirement already satisfied: cloudpickle<4 in c:\users\bishw\anaconda3\lib\site-packages (from mlflow-skinny==2.15.1->mlflow) (2.2.1)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==2.15.1->mlflow)
#   Obtaining dependency information for databricks-sdk<1,>=0.20.0 from https://files.pythonhosted.org/packages/ad/14/005d6904ffbf477e67913f6480b22522e583ae25160d1fce30d15c1dfa94/databricks_sdk-0.30.0-py3-none-any.whl.metadata
#   Downloading databricks_sdk-0.30.0-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: entrypoints<1 in c:\users\bishw\anaconda3\lib\site-packages (from mlflow-skinny==2.15.1->mlflow) (0.4)
# Collecting gitpython<4,>=3.1.9 (from mlflow-skinny==2.15.1->mlflow)
#   Obtaining dependency information for gitpython<4,>=3.1.9 from https://files.pythonhosted.org/packages/e9/bd/cc3a402a6439c15c3d4294333e13042b915bbeab54edc457c723931fed3f/GitPython-3.1.43-py3-none-any.whl.metadata
#   Downloading GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: importlib-metadata!=4.7.0,<8,>=3.7.0 in c:\users\bishw\anaconda3\lib\site-packages (from mlflow-skinny==2.15.1->mlflow) (6.0.0)
# Collecting opentelemetry-api<3,>=1.9.0 (from mlflow-skinny==2.15.1->mlflow)
#   Obtaining dependency information for opentelemetry-api<3,>=1.9.0 from https://files.pythonhosted.org/packages/e3/a7/6322d1d7a1fb926e8b99208c27730f21217da2f1e0e11dab48a78a0427a4/opentelemetry_api-1.26.0-py3-none-any.whl.metadata
#   Downloading opentelemetry_api-1.26.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-sdk<3,>=1.9.0 (from mlflow-skinny==2.15.1->mlflow)
#   Obtaining dependency information for opentelemetry-sdk<3,>=1.9.0 from https://files.pythonhosted.org/packages/92/f1/a9b550d0f9c049653dd2eab45cecf8fe4baa9795ed143d87834056ffabaf/opentelemetry_sdk-1.26.0-py3-none-any.whl.metadata
#   Downloading opentelemetry_sdk-1.26.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: packaging<25 in c:\users\bishw\anaconda3\lib\site-packages (from mlflow-skinny==2.15.1->mlflow) (23.1)
# Collecting protobuf<6,>=3.12.0 (from mlflow-skinny==2.15.1->mlflow)
#   Obtaining dependency information for protobuf<6,>=3.12.0 from https://files.pythonhosted.org/packages/a4/30/cb5395acd5f65edc0dee77bdd134fe556c52fade2ad3ea9ac2676d01effe/protobuf-5.27.3-cp310-abi3-win_amd64.whl.metadata
#   Downloading protobuf-5.27.3-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# Requirement already satisfied: pytz<2025 in c:\users\bishw\anaconda3\lib\site-packages (from mlflow-skinny==2.15.1->mlflow) (2023.3.post1)
# Requirement already satisfied: pyyaml<7,>=5.1 in c:\users\bishw\anaconda3\lib\site-packages (from mlflow-skinny==2.15.1->mlflow) (6.0)
# Requirement already satisfied: requests<3,>=2.17.3 in c:\users\bishw\anaconda3\lib\site-packages (from mlflow-skinny==2.15.1->mlflow) (2.31.0)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in c:\users\bishw\anaconda3\lib\site-packages (from mlflow-skinny==2.15.1->mlflow) (0.4.4)
# Collecting Mako (from alembic!=1.10.0,<2->mlflow)
#   Obtaining dependency information for Mako from https://files.pythonhosted.org/packages/03/62/70f5a0c2dd208f9f3f2f9afd103aec42ee4d9ad2401d78342f75e9b8da36/Mako-1.3.5-py3-none-any.whl.metadata
#   Downloading Mako-1.3.5-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4 in c:\users\bishw\anaconda3\lib\site-packages (from alembic!=1.10.0,<2->mlflow) (4.7.1)
# Requirement already satisfied: pywin32>=304 in c:\users\bishw\anaconda3\lib\site-packages (from docker<8,>=4.0.0->mlflow) (305.1)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\bishw\anaconda3\lib\site-packages (from docker<8,>=4.0.0->mlflow) (1.26.16)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\users\bishw\anaconda3\lib\site-packages (from Flask<4->mlflow) (2.2.3)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\bishw\anaconda3\lib\site-packages (from Flask<4->mlflow) (2.0.1)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow)
#   Obtaining dependency information for graphql-core<3.3,>=3.1 from https://files.pythonhosted.org/packages/f8/39/e5143e7ec70939d2076c1165ae9d4a3815597019c4d797b7f959cf778600/graphql_core-3.2.3-py3-none-any.whl.metadata
#   Downloading graphql_core-3.2.3-py3-none-any.whl.metadata (10 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow)
#   Obtaining dependency information for graphql-relay<3.3,>=3.1 from https://files.pythonhosted.org/packages/74/16/a4cf06adbc711bd364a73ce043b0b08d8fa5aae3df11b6ee4248bcdad2e0/graphql_relay-3.2.0-py3-none-any.whl.metadata
#   Downloading graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Collecting aniso8601<10,>=8 (from graphene<4->mlflow)
#   Obtaining dependency information for aniso8601<10,>=8 from https://files.pythonhosted.org/packages/e3/04/e97c12dc034791d7b504860acfcdd2963fa21ae61eaca1c9d31245f812c3/aniso8601-9.0.1-py2.py3-none-any.whl.metadata
#   Downloading aniso8601-9.0.1-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\bishw\anaconda3\lib\site-packages (from Jinja2<4,>=3.0->mlflow) (2.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\bishw\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\bishw\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\bishw\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\bishw\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\bishw\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\bishw\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\bishw\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\bishw\anaconda3\lib\site-packages (from pandas<3->mlflow) (2023.3)
# Requirement already satisfied: six in c:\users\bishw\anaconda3\lib\site-packages (from querystring-parser<2->mlflow) (1.16.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\bishw\anaconda3\lib\site-packages (from scikit-learn<2->mlflow) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\bishw\anaconda3\lib\site-packages (from scikit-learn<2->mlflow) (2.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\bishw\anaconda3\lib\site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (2.0.1)
# Requirement already satisfied: colorama in c:\users\bishw\anaconda3\lib\site-packages (from click<9,>=7.0->mlflow-skinny==2.15.1->mlflow) (0.4.6)
# Collecting google-auth~=2.0 (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.15.1->mlflow)
#   Obtaining dependency information for google-auth~=2.0 from https://files.pythonhosted.org/packages/bb/fb/9af9e3f2996677bdda72734482934fe85a3abde174e5f0783ac2f817ba98/google_auth-2.34.0-py2.py3-none-any.whl.metadata
#   Downloading google_auth-2.34.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython<4,>=3.1.9->mlflow-skinny==2.15.1->mlflow)
#   Obtaining dependency information for gitdb<5,>=4.0.1 from https://files.pythonhosted.org/packages/fd/5b/8f0c4a5bb9fd491c277c21eff7ccae71b47d43c4446c9d0c6cff2fe8c2c4/gitdb-4.0.11-py3-none-any.whl.metadata
#   Downloading gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: zipp>=0.5 in c:\users\bishw\anaconda3\lib\site-packages (from importlib-metadata!=4.7.0,<8,>=3.7.0->mlflow-skinny==2.15.1->mlflow) (3.11.0)
# Collecting deprecated>=1.2.6 (from opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.15.1->mlflow)
#   Obtaining dependency information for deprecated>=1.2.6 from https://files.pythonhosted.org/packages/20/8d/778b7d51b981a96554f29136cd59ca7880bf58094338085bcf2a979a0e6a/Deprecated-1.2.14-py2.py3-none-any.whl.metadata
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting opentelemetry-semantic-conventions==0.47b0 (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.15.1->mlflow)
#   Obtaining dependency information for opentelemetry-semantic-conventions==0.47b0 from https://files.pythonhosted.org/packages/00/c2/ca5cef8e4cd8eec5a95deed95ec3f6005e499fd9d17ca08731ced03a6921/opentelemetry_semantic_conventions-0.47b0-py3-none-any.whl.metadata
#   Downloading opentelemetry_semantic_conventions-0.47b0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bishw\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.15.1->mlflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bishw\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.15.1->mlflow) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bishw\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.15.1->mlflow) (2023.7.22)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\bishw\anaconda3\lib\site-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.15.1->mlflow) (1.14.1)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.15.1->mlflow)
#   Obtaining dependency information for smmap<6,>=3.0.1 from https://files.pythonhosted.org/packages/a7/a5/10f97f73544edcdef54409f1d839f6049a0d79df68adbc1ceb24d1aaca42/smmap-5.0.1-py3-none-any.whl.metadata
#   Downloading smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\bishw\anaconda3\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.15.1->mlflow) (0.2.8)
# Collecting rsa<5,>=3.1.4 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.15.1->mlflow)
#   Obtaining dependency information for rsa<5,>=3.1.4 from https://files.pythonhosted.org/packages/49/97/fa78e3d2f65c02c8e1268b9aba606569fe97f6c8f7c2d74394553347c145/rsa-4.9-py3-none-any.whl.metadata
#   Downloading rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\bishw\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.15.1->mlflow) (0.4.8)
# Using cached mlflow-2.15.1-py3-none-any.whl (26.3 MB)
# Using cached mlflow_skinny-2.15.1-py3-none-any.whl (5.5 MB)
# Using cached alembic-1.13.2-py3-none-any.whl (232 kB)
# Using cached docker-7.1.0-py3-none-any.whl (147 kB)
# Using cached graphene-3.3-py2.py3-none-any.whl (128 kB)
# Using cached querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Using cached waitress-3.0.0-py3-none-any.whl (56 kB)
# Using cached aniso8601-9.0.1-py2.py3-none-any.whl (52 kB)
# Downloading cachetools-5.5.0-py3-none-any.whl (9.5 kB)
# Using cached databricks_sdk-0.30.0-py3-none-any.whl (538 kB)
# Using cached GitPython-3.1.43-py3-none-any.whl (207 kB)
# Using cached graphql_core-3.2.3-py3-none-any.whl (202 kB)
# Using cached graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Using cached opentelemetry_api-1.26.0-py3-none-any.whl (61 kB)
# Using cached opentelemetry_sdk-1.26.0-py3-none-any.whl (109 kB)
# Using cached opentelemetry_semantic_conventions-0.47b0-py3-none-any.whl (138 kB)
# Downloading protobuf-5.27.3-cp310-abi3-win_amd64.whl (426 kB)
#    ---------------------------------------- 0.0/426.9 kB ? eta -:--:--
#    ------ --------------------------------- 71.7/426.9 kB 3.8 MB/s eta 0:00:01
#    --------------------- ------------------ 225.3/426.9 kB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 426.9/426.9 kB 3.3 MB/s eta 0:00:00
# Using cached Mako-1.3.5-py3-none-any.whl (78 kB)
# Using cached Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Using cached gitdb-4.0.11-py3-none-any.whl (62 kB)
# Downloading google_auth-2.34.0-py2.py3-none-any.whl (200 kB)
#    ---------------------------------------- 0.0/200.9 kB ? eta -:--:--
#    --------------------------------------- 200.9/200.9 kB 11.9 MB/s eta 0:00:00
# Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Using cached smmap-5.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: aniso8601, waitress, smmap, rsa, querystring-parser, protobuf, Mako, graphql-core, deprecated, cachetools, opentelemetry-api, graphql-relay, google-auth, gitdb, docker, alembic, opentelemetry-semantic-conventions, graphene, gitpython, databricks-sdk, opentelemetry-sdk, mlflow-skinny, mlflow
# Successfully installed Mako-1.3.5 alembic-1.13.2 aniso8601-9.0.1 cachetools-5.5.0 databricks-sdk-0.30.0 deprecated-1.2.14 docker-7.1.0 gitdb-4.0.11 gitpython-3.1.43 google-auth-2.34.0 graphene-3.3 graphql-core-3.2.3 graphql-relay-3.2.0 mlflow-2.15.1 mlflow-skinny-2.15.1 opentelemetry-api-1.26.0 opentelemetry-sdk-1.26.0 opentelemetry-semantic-conventions-0.47b0 protobuf-5.27.3 querystring-parser-1.2.4 rsa-4.9 smmap-5.0.1 waitress-3.0.0

# %%
import math
import numpy as np
import pandas as pd
import random
import os

import cv2
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report

import tensorflow as tf
from tensorflow.keras import optimizers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Flatten, Dense, Conv2D, GlobalAveragePooling2D
from tensorflow.keras.layers import Dropout, BatchNormalization, Activation
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %% [markdown]
# # Data Collection Combining and Saving

# %% [markdown]
# ### Setting directories

# %%
train_data_dir = r"C:\laragon\www\8th_sem_project\emotion-detection-and-music-recommendation\dataset\input\\fer2013\\train\\"
test_data_dir = r"C:\laragon\www\8th_sem_project\emotion-detection-and-music-recommendation\dataset\input\\fer2013\\test\\"

# %% [markdown]
# ### Collect images from each train and test dataset and save it into a numpy array

# %%
def collect_data(directory):
    data = []
    labels = []

    total = 0

    for index, label  in enumerate(os.listdir(directory)):

        for image_file in os.listdir(os.path.join(directory, label)):

            img = cv2.imread(os.path.join(os.path.join(directory, label, image_file)))

            data.append(img)
            labels.append(label)

            total += 1

    print(f'Total data saved = {total}')
    return data,labels

# %%
final_data = []
final_labels = []

# Getting train_datas
print("Train Datas")

train_data, train_labels = collect_data(train_data_dir)
final_data.extend(train_data)
final_labels.extend(train_labels)

# Getting test_datas
print("Test Datas")

test_data, test_labels = collect_data(test_data_dir)
final_data.extend(test_data)
final_labels.extend(test_labels)
# Out:
# Train Datas
# Total data saved = 28709
# Test Datas
# Total data saved = 7178

# %% [markdown]
# ### Shuffle

# %%
combined_list = list(zip(final_data,final_labels))
shuffled_combined_list = random.sample(combined_list,len(combined_list))

final_data,final_labels = zip(*shuffled_combined_list)

# %%
data = np.array(final_data)
labels = np.array(final_labels)

# %% [markdown]
# ### Saving to .npy file so we can load datasets later

# %%
np.save("data_numpy/emotion_data.npy",data)
np.save("data_numpy/emotion_labels.npy",labels)

# %%
data = np.load('data_numpy/emotion_data.npy')
labels = np.load('data_numpy/emotion_labels.npy')

# %% [markdown]
# # Visualization

# %% [markdown]
# ### Visualizing Labels

# %%
categories = ['angry','disgust','fear','happy','neutral','sad','surprise']

# %%
# Total Numer of Images
print(f"Total Number of Images : {len(labels)}")

# For coloring purposes
color_map = {'angry' : 'red','disgust' : 'green','fear' : 'purple','happy' : 'skyblue','neutral' : 'lightgray','sad' : 'blue','surprise' : 'magenta'}

# Plotting bar graph
label_series = pd.Series(labels)
ax = label_series.value_counts().sort_index(ascending=True).plot(kind="bar",color=[color_map[x] for x in categories],xlabel='categories',ylabel='count');

for bar in ax.patches:
    ax.annotate(str(bar.get_height()), (bar.get_x() + bar.get_width() / 2., bar.get_height()),
                ha='center', va='bottom')
# Out:
# Total Number of Images : 35887

# %% [markdown]
# ### Visualizing Images

# %%
def random_value_for_index(list, target_value):
    indices = [index for index,value in enumerate(list) if value == target_value]
    return random.choice(indices)

fig, axs = plt.subplots(1,7 ,figsize=(16,16))

for index,category in enumerate(categories):
    # Select random image index from specific category
    random_index = random_value_for_index(labels,category)

    # Plot the random image
    axs[index].imshow(data[random_index])
    axs[index].axis('off')
    axs[index].set_title(category)

plt.subplots_adjust(wspace = 0.1,hspace = 0.1)
plt.show()

# %% [markdown]
# ### Splitting the data into training and validation set.

# %%
X_train, X_valid, y_train, y_valid = train_test_split(data,
                                                      labels,
                                                      shuffle = True,
                                                      test_size = 0.2,
                                                      random_state = 42)
X_train.shape, X_valid.shape, y_train.shape, y_valid.shape
# Out:
# ((28709, 48, 48, 3), (7178, 48, 48, 3), (28709,), (7178,))

# %%
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train)
y_valid = label_encoder.transform(y_valid)

# %%
img_width = X_train.shape[1]
img_height = X_train.shape[2]
img_depth = X_train.shape[3]
num_classes = 7

# %% [markdown]
# ### Normalizing results, as neural networks are very sensitive to unnormalized data.

# %%
X_train = X_train / 255.
X_valid = X_valid / 255.

# %%
vgg = tf.keras.applications.VGG19(weights = 'imagenet',
                                  include_top = False,
                                  input_shape = (48, 48, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 ━━━━━━━━━━━━━━━━━━━━ 6s 0us/step

# %% [markdown]
# This code makes all layers of a VGG19 model non-trainable. This allows the model to be applied to a new problem using only pre-learned features, rather than reflecting changes in the training data to the model, while preserving the pre-trained weights. This is a technique often used in transfer learning applications.
#
# In particular, while developing a facial emotion recognition model using the VGG19 model, the pre-trained weights of the model are preserved, allowing it to be used in solving a new emotion recognition problem. In this way, it may be possible to obtain better results using less data.

# %%
# for layer in vgg.layers:
    # layer.trainable = False

# %%
vgg.summary()
# Out:
# Model: "vgg19"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 48, 48, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 48, 48, 64)     │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 48, 48, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 24, 24, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 24, 24, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 12, 12, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 12, 12, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 12, 12, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv4 (Conv2D)           │ (None, 12, 12, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 6, 6, 512)      │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 6, 6, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 6, 6, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv4 (Conv2D)           │ (None, 6, 6, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 3, 3, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 3, 3, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 3, 3, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 3, 3, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv4 (Conv2D)           │ (None, 3, 3, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 1, 1, 512)      │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 20,024,384 (76.39 MB)
#  Trainable params: 20,024,384 (76.39 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
def build_model(bottom_model, classes):
    model = bottom_model.layers[-2].output
    model = GlobalAveragePooling2D()(model)
    model = Dense(classes, activation = 'softmax', name = 'out_layer')(model)

    return model

# %%
head = build_model(vgg, num_classes)

model = Model(inputs = vgg.input, outputs = head)

print(model.summary())
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 48, 48, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 48, 48, 64)     │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 48, 48, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 24, 24, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 24, 24, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 12, 12, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 12, 12, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 12, 12, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv4 (Conv2D)           │ (None, 12, 12, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 6, 6, 512)      │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 6, 6, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 6, 6, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv4 (Conv2D)           │ (None, 6, 6, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 3, 3, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 3, 3, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 3, 3, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 3, 3, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv4 (Conv2D)           │ (None, 3, 3, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ out_layer (Dense)               │ (None, 7)              │         3,591 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 20,027,975 (76.40 MB)
#  Trainable params: 20,027,975 (76.40 MB)
#  Non-trainable params: 0 (0.00 B)
# None

# %% [markdown]
# ### I used two callbacks one is `early stopping` for avoiding overfitting training data and other `ReduceLROnPlateau` for learning rate.

# %%
early_stopping = EarlyStopping(monitor = 'val_accuracy',
                               min_delta = 0.00005,
                               patience = 11,
                               verbose = 1,
                               restore_best_weights = True,)

lr_scheduler = ReduceLROnPlateau(monitor = 'val_accuracy',
                                 factor = 0.5,
                                 patience = 7,
                                 min_lr = 1e-7,
                                 verbose = 1,)

callbacks = [early_stopping,lr_scheduler,]

# %% [markdown]
# ### As the data in hand is less as compared to the task so ImageDataGenerator is good to go.

# %%
train_datagen = ImageDataGenerator(rotation_range = 15,
                                   width_shift_range = 0.15,
                                   height_shift_range = 0.15,
                                   shear_range = 0.15,
                                   zoom_range = 0.15,
                                   horizontal_flip = True,)
train_datagen.fit(X_train)

# %%
# batch size of 32 performs the best.
batch_size = 32
epochs = 50
optims = [optimizers.Adam(learning_rate = 0.0001, beta_1 = 0.9, beta_2 = 0.999),]

model.compile(loss = 'sparse_categorical_crossentropy',
              optimizer = optims[0],
              metrics = ['accuracy'])

# %%
history = model.fit(
    train_datagen.flow(X_train, y_train, batch_size=batch_size),
    validation_data=(X_valid, y_valid),
    steps_per_epoch=len(X_train) // batch_size,
    epochs=epochs,
    callbacks=callbacks
)
# Out:
# Epoch 1/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 1008s 1s/step - accuracy: 0.5654 - loss: 1.1494 - val_accuracy: 0.5805 - val_loss: 1.1140 - learning_rate: 1.0000e-04
# Epoch 2/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 36s 40ms/step - accuracy: 0.6250 - loss: 1.0628 - val_accuracy: 0.5828 - val_loss: 1.1087 - learning_rate: 1.0000e-04
# Epoch 3/50
# 273/897 ━━━━━━━━━━━━━━━━━━━━ 2:36:13 15s/step - accuracy: 0.5835 - loss: 1.1108
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 history = model.fit(
#       2     train_datagen.flow(X_train, y_train, batch_size=batch_size),
#       3     validation_data=(X_valid, y_valid),
#       4     steps_per_epoch=len(X_train) // batch_size,
#       5     epochs=epochs,
#       6     callbacks=callbacks
#       7 )
#
# File c:\Users\bishw\miniconda3\lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\bishw\miniconda3\lib\site-packages\keras\src\backend\tensorflow\trainer.py:318, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     316 for step, iterator in epoch_iterator.enumerate_epoch():
#     317     callbacks.on_train_batch_begin(step)
# --> 318     logs = self.train_function(iterator)
#     319     logs = self._pythonify_logs(logs)
#     320     callbacks.on_train_batch_end(step, logs)
#
# File c:\Users\bishw\miniconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\bishw\miniconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\bishw\miniconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File c:\Users\bishw\miniconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Users\bishw\miniconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\bishw\miniconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File c:\Users\bishw\miniconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File c:\Users\bishw\miniconda3\lib\site-packages\tensorflow\python\eager\context.py:1552, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1550 cancellation_context = cancellation.context()
#    1551 if cancellation_context is None:
# -> 1552   outputs = execute.execute(
#    1553       name.decode("utf-8"),
#    1554       num_outputs=num_outputs,
#    1555       inputs=tensor_inputs,
#    1556       attrs=attrs,
#    1557       ctx=self,
#    1558   )
#    1559 else:
#    1560   outputs = execute.execute_with_cancellation(
#    1561       name.decode("utf-8"),
#    1562       num_outputs=num_outputs,
#    (...)
#    1566       cancellation_manager=cancellation_context,
#    1567   )
#
# File c:\Users\bishw\miniconda3\lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# # Save Logs

# %%
# Create a DataFrame from the history object
history_df = pd.DataFrame(history.history)

# Save the DataFrame to a CSV file
history_df.to_csv('logs/training_history.csv', index=False)

# %%
sns.set()
fig = plt.figure(0, (12, 4))

ax = plt.subplot(1, 2, 1)
sns.lineplot(x=history.epoch, y=history.history['accuracy'], label='train')
sns.lineplot(x=history.epoch, y=history.history['val_accuracy'], label='valid')
plt.title('Accuracy')
plt.tight_layout()

ax = plt.subplot(1, 2, 2)
sns.lineplot(x=history.epoch, y=history.history['loss'], label='train')
sns.lineplot(x=history.epoch, y=history.history['val_loss'], label='valid')
plt.title('Loss')
plt.tight_layout()

# plt.savefig('epoch_history_dcnn.png')
plt.show()

# %% [markdown]
# # Save Model

# %%
model.save('models/vgg.h5')

# %% [markdown]
# # Load Model

# %%
model = tf.keras.models.load_model('models/vgg.h5')

# %% [markdown]
# # Metrices

# %%
import numpy as np

# Get predictions from your model
y_pred = model.predict(X_valid)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = label_encoder.transform(y_valid)

# %%
from sklearn.metrics import classification_report

report = classification_report(y_valid, y_pred_classes, target_names=categories)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.29      0.53      0.37       978
#      disgust       0.00      0.00      0.00       109
#         fear       0.24      0.22      0.23       991
#        happy       0.76      0.67      0.71      1816
#      neutral       0.41      0.41      0.41      1271
#          sad       0.50      0.09      0.15      1250
#     surprise       0.31      0.55      0.40       763
#
#     accuracy                           0.42      7178
#    macro avg       0.36      0.35      0.32      7178
# weighted avg       0.46      0.42      0.40      7178

# %%
cf_matrix = confusion_matrix(y_valid, y_pred_classes)
cm_array_df = pd.DataFrame(cf_matrix, index=categories, columns=categories)
sns.heatmap(cm_array_df, annot=True, annot_kws={"size": 12},fmt=".0f")
# Out:
# <Axes: >

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file into a DataFrame
history_df = pd.read_csv('training_history_vgg.csv')  # Replace 'your_history.csv' with your actual file name

# Extract relevant columns
train_loss = history_df['loss']
train_accuracy = history_df['accuracy']
val_loss = history_df['val_loss']
val_accuracy = history_df['val_accuracy']
lr = history_df['lr']

# Create subplots
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 8))

# Plot loss
axes[0, 0].plot(history_df.index, train_loss, label='Training Loss')
axes[0, 0].plot(history_df.index, val_loss, label='Validation Loss')
axes[0, 0].set_title('Loss')
axes[0, 0].legend()

# Plot accuracy
axes[0, 1].plot(history_df.index, train_accuracy, label='Training Accuracy')
axes[0, 1].plot(history_df.index, val_accuracy, label='Validation Accuracy')
axes[0, 1].set_title('Accuracy')
axes[0, 1].legend()

# Plot learning rate
axes[1, 0].plot(history_df.index, lr, label='Learning Rate')
axes[1, 0].set_title('Learning Rate')
axes[1, 0].legend()

# Remove the empty subplot
fig.delaxes(axes[1, 1])

# Adjust layout and show plot
plt.tight_layout()
plt.show()
